# %% [markdown]
# # Solución al ejercicio 1

# %%
# importamos librerias
import sqlite3

# %%
#2. Conéctate a una base de datos llamada `tienda.db`
connection = sqlite3.connect("tienda.db")

# %%
#3. Crea una tabla llamada `productos` con las siguientes columnas:
cursor=connection.cursor()
cursor.execute("CREATE TABLE productos(id integer,nombre text ,precio real,stock integer)")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[10], line 3
#       1 #3. Crea una tabla llamada `productos` con las siguientes columnas:
#       2 cursor=connection.cursor()
# ----> 3 cursor.execute("CREATE TABLE productos(id integer,nombre text ,precio real,stock integer)")
#
# OperationalError: table productos already exists

# %%
#4 cerrar conexcion
connection.close()
