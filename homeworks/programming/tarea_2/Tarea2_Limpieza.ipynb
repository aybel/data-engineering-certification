# %% [markdown]
# # Tarea 2: Limpieza y Estandarización de Datos
#
# **Objetivo:** Corregir todos los problemas de calidad identificados en la Tarea 1.
#
# Este notebook implementa funciones para limpiar y estandarizar los datos de transacciones.

# %% [markdown]
# ## 1. Cargar librerías y dependencias

# %%
import pandas as pd
import numpy as np
import json
from datetime import datetime
import re
import os

print("✓ Librerías importadas correctamente:")
print(f"  - pandas {pd.__version__}")
print(f"  - numpy {np.__version__}")
# Out:
# ✓ Librerías importadas correctamente:
#   - pandas 1.5.3
#   - numpy 1.24.3

# %% [markdown]
# ## 2. Cargar datos raws y definir funciones de limpieza

# %%
# Cargar datos
csv_path =  "../../data/raw/ventas.csv"
print(f"Cargando datos desde: {csv_path}")

if os.path.exists(csv_path):
    df_raw = pd.read_csv(csv_path)
    print(f"✓ Datos cargados exitosamente")
    print(f"  - Filas: {len(df_raw)}")
    print(f"  - Columnas: {len(df_raw.columns)}")
    print(f"\nPrimeras filas del dataset raw:")
    print(df_raw.head())
else:
    print(f"✗ Archivo no encontrado: {csv_path}")
    print("Verifica que la Tarea 1 fue ejecutada correctamente")

# Guardar copia del original para comparación
df_backup = df_raw.copy()
# Out:
# Cargando datos desde: ../../data/raw/ventas.csv
# ✓ Datos cargados exitosamente
#   - Filas: 20000
#   - Columnas: 31
#
# Primeras filas del dataset raw:
#    id_venta       fecha   año  mes dia_semana  semana_numero    producto  \
# 0         1  2024-12-03  2024   12    Tuesday             49  Disco Duro
# 1         2  08-26-2024  2024    8     Monday             35     Teclado
# 2         3  2024-08-21  2024    8  Wednesday             34     Monitor
# 3         4  2024-07-07  2024    7     Sunday             27       Mouse
# 4         5  2023-05-15  2023    5     Monday             20         NaN
#
#         categoria cantidad precio_unitario  ...  cliente_antiguedad_dias  \
# 0     Electrónica       46             976  ...                        1
# 1             NaN       57            1309  ...                      219
# 2      Accesorios        8             727  ...                        7
# 3  Almacenamiento       15             705  ...                       99
# 4     Electrónica       56            1500  ...                      184
#
#   vendedor_id  vendedor_experiencia_meses  promocion_aplicada cupon_usado  \
# 0       Sofia                         6.0         CyberMonday          No
# 1       Laura                        24.0              Verano          Sí
# 2       Sofia                         6.0         CyberMonday       False
# 3         Ana                        36.0       Sin promoción       False
# 4       Sofia                         6.0                 NaN        True
#
#   puntuacion_cliente tiempo_entrega_dias fecha_registro_cliente  \
# 0                  3                   3             2024-12-02
# 1                  3                  15             2024-01-20
# 2                  1                   3             2024-08-14
# 3                  1                  12             2024-03-30
# 4                  2                   5             2022-11-12
#
#   acumulado_mes_producto ranking_ciudad_mes
# 0                35916.8                1.0
# 1               64913.31                1.0
# 2                5699.68                2.0
# 3                 5499.0                1.0
# 4                84000.0                1.0
#
# [5 rows x 31 columns]

# %%
# Funciones de limpieza requeridas

def limpiar_montos(valor):
    """
    Convierte montos a float, elimina $, corrige negativos y maneja nulos.
    """
    if pd.isna(valor):
        return np.nan
    
    # Convertir a string y eliminar espacios
    valor_str = str(valor).strip()
    
    # Si está vacío, retornar NaN
    if valor_str == '' or valor_str.upper() == 'NAN':
        return np.nan
    
    # Eliminar signo de dólar y espacios
    valor_str = valor_str.replace('$', '').replace(' ', '')
    
    try:
        monto = float(valor_str)
        # Si es negativo, convertir a positivo
        if monto < 0:
            monto = abs(monto)
        return monto
    except ValueError:
        return np.nan

def estandarizar_fechas(valor):
    """
    Unififica el formato de fechas a YYYY-MM-DD.
    """
    if pd.isna(valor):
        return np.nan
    
    valor_str = str(valor).strip()
    
    if valor_str == '' or valor_str.upper() == 'NAN':
        return np.nan
    
    # Intentar varios formatos comunes
    formatos = ['%Y-%m-%d', '%d/%m/%Y', '%m/%d/%Y', '%Y/%m/%d', '%d-%m-%Y']
    
    for fmt in formatos:
        try:
            fecha = datetime.strptime(valor_str, fmt)
            return fecha.strftime('%Y-%m-%d')
        except ValueError:
            continue
    
    # Si ningún formato funciona, retornar NaN
    return np.nan

def corregir_estados(valor):
    """
    Asigna 'DESCONOCIDO' a valores vacíos en el estado.
    """
    if pd.isna(valor) or valor == '' or str(valor).strip() == '':
        return 'DESCONOCIDO'
    return str(valor).strip()

def corregir_tiendas(valor):
    """
    Asigna 'TIENDA_SIN_ESPECIFICAR' a valores nulos.
    """
    if pd.isna(valor) or valor == '' or str(valor).strip() == '':
        return 'TIENDA_SIN_ESPECIFICAR'
    return str(valor).strip()

def corregir_clientes(valor):
    """
    Asigna 'DESCONOCIDO' a valores nulos en customer_id.
    """
    if pd.isna(valor) or valor == '' or str(valor).strip() == '':
        return 'DESCONOCIDO'
    return str(valor).strip()

def estandarizar_textos_ingles(texto):
    """
    Convierte texto de inglés a español
    """
    # Verificar si el texto es nulo o vacío
    if pd.isna(texto) or texto == "" or str(texto).strip() == '':
        return 'DESCONOCIDO'
    
    # Traducir solo si hay texto válido
    try:
        traduccion = translator.translate(texto, src='en', dest='es')
        return traduccion.text
    except Exception as e:
        print(f"Error traduciendo '{texto}': {e}")
        return 'ERROR_TRADUCCION'  # o return 'ERROR_TRADUCCION'

print("✓ Funciones de limpieza definidas correctamente")
# Out:
# ✓ Funciones de limpieza definidas correctamente

# %% [markdown]
# ## 3. Aplicar las funciones de limpieza al dataset

# %%
print("Aplicando funciones de limpieza...\n")

# Crear copia para limpiar
df_clean = df_raw.copy()

# Aplicar funciones según las columnas disponibles
columnas = df_clean.columns
print(f"Columnas disponibles: {list(columnas)}")

# Limpiar montos (buscar columna de monto)
monto_cols = [col for col in columnas if 'precio_unitario' in col.lower() or 'amount' in col.lower()]
if monto_cols:
    for col in monto_cols:
        print(f"\n✓ Limpiando columna '{col}'...")
        df_clean[col] = df_clean[col].apply(limpiar_montos)
        nulos_antes = df_backup[col].isna().sum()
        nulos_despues = df_clean[col].isna().sum()
        print(f"  Nulos: {nulos_antes} → {nulos_despues}")

# Estandarizar fechas (buscar columna de fecha)
fecha_cols = [col for col in columnas if 'fecha' in col.lower() or 'date' in col.lower()]
if fecha_cols:
    for col in fecha_cols:
        print(f"\n✓ Estandarizando columna '{col}'...")
        df_clean[col] = df_clean[col].apply(estandarizar_fechas)
        nulos_antes = df_backup[col].isna().sum()
        nulos_despues = df_clean[col].isna().sum()
        print(f"  Nulos: {nulos_antes} → {nulos_despues}")
        
# Estandarizar fechas (buscar columna de fecha_registro_cliente)
fecha_cols = [col for col in columnas if 'fecha_registro_cliente' in col.lower() or 'date' in col.lower()]
if fecha_cols:
    for col in fecha_cols:
        print(f"\n✓ Estandarizando columna '{col}'...")
        df_clean[col] = df_clean[col].apply(estandarizar_fechas)
        nulos_antes = df_backup[col].isna().sum()
        nulos_despues = df_clean[col].isna().sum()
        print(f"  Nulos: {nulos_antes} → {nulos_despues}")

# Estandarizar dia de la semana a español 
# Opción 2: Buscar columnas de tipo objeto (texto) automáticamente
columnas_texto_auto=["dia_semana"]
columnas_texto_auto = df_clean.select_dtypes(include=['object']).columns.tolist()
for col in columnas_texto_auto:
    print(f"\n✓ Traduciendo columna '{col}'...")
    df_clean[col] = df_clean[col].apply(estandarizar_textos_ingles)

print("\n✓ Limpieza completada")
print(f"\nPrimeras filas del dataset limpio:")
print(df_clean.head())
# Out:
# Aplicando funciones de limpieza...
#
# Columnas disponibles: ['id_venta', 'fecha', 'año', 'mes', 'dia_semana', 'semana_numero', 'producto', 'categoria', 'cantidad', 'precio_unitario', 'descuento', 'monto_total', 'costo_unitario', 'margen_beneficio', 'estado', 'ciudad', 'region', 'metodo_pago', 'canal_venta', 'cliente_id', 'categoria_cliente', 'cliente_antiguedad_dias', 'vendedor_id', 'vendedor_experiencia_meses', 'promocion_aplicada', 'cupon_usado', 'puntuacion_cliente', 'tiempo_entrega_dias', 'fecha_registro_cliente', 'acumulado_mes_producto', 'ranking_ciudad_mes']
#
# ✓ Limpiando columna 'precio_unitario'...
#   Nulos: 0 → 1071
#
# ✓ Estandarizando columna 'fecha'...
#   Nulos: 0 → 1228
#
# ✓ Estandarizando columna 'fecha_registro_cliente'...
#   Nulos: 0 → 1333
#
# ✓ Estandarizando columna 'fecha_registro_cliente'...
#   Nulos: 0 → 1333
#
# ✓ Traduciendo columna 'fecha'...
# Error traduciendo '2024-12-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-31': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-31': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-31': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-31': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-31': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-31': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-16': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-11': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-31': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-06': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-08': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-23': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-08-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-02': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-09-30': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-18': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-28': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-09-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-10': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-01-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-04-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-06-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-13': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-15': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-29': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-03-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-02-26': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-07': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-05-09': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-10-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-12-03': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-06-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-07-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-04-21': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-01': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-10-14': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-05': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-24': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-07-27': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-05-20': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-11-12': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2024-11-19': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-03-25': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-08-17': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-01-22': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-12-04': 'coroutine' object has no attribute 'text'
# Error traduciendo '2023-02-27': 'coroutine' object has no attribute 'text'
# ...
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Tuesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Friday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Monday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Sunday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Saturday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Wednesday': 'coroutine' object has no attribute 'text'
# Error traduciendo 'Thursday': 'coroutine' object has no attribute 'text'
# /usr/local/lib/python3.11/site-packages/pandas/core/apply.py:1174: RuntimeWarning: coroutine 'Translator.translate' was never awaited
#   mapped = lib.map_infer(
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## 4. Generar reporte comparativo antes/después

# %%
# Generar reporte comparativo
print("\n" + "="*60)
print("REPORTE COMPARATIVO - ANTES vs DESPUÉS DE LIMPIEZA")
print("="*60)

reporte = {
    "fecha_ejecucion": datetime.now().isoformat(),
    "resumen_general": {
        "total_registros": len(df_clean),
        "total_columnas": len(df_clean.columns),
    },
    "analisis_nulos": {}
}

print("\n📊 Análisis de Nulos por Columna:")
print("-" * 60)
print(f"{'Columna':<20} {'Antes':<15} {'Después':<15} {'Mejora':<10}")
print("-" * 60)

for col in df_clean.columns:
    nulos_antes = df_backup[col].isna().sum()
    nulos_despues = df_clean[col].isna().sum()
    mejora = nulos_antes - nulos_despues
    porcentaje_antes = (nulos_antes / len(df_backup)) * 100
    porcentaje_despues = (nulos_despues / len(df_clean)) * 100
    
    print(f"{col:<20} {nulos_antes} ({porcentaje_antes:.1f}%) {nulos_despues} ({porcentaje_despues:.1f}%) {mejora:+d}")
    
    reporte["analisis_nulos"][col] = {
        "nulos_antes": int(nulos_antes),
        "porcentaje_antes": round(porcentaje_antes, 2),
        "nulos_despues": int(nulos_despues),
        "porcentaje_despues": round(porcentaje_despues, 2),
        "mejora": int(mejora)
    }

print("\n✓ Estadísticas del dataset limpio:")
print(f"  - Registros totales: {len(df_clean)}")
print(f"  - Registros sin nulos en ninguna columna: {df_clean.dropna().shape[0]}")
print(f"  - Registros con al menos un nulo: {df_clean[df_clean.isna().any(axis=1)].shape[0]}")

print("\nTipos de datos después de limpieza:")
print(df_clean.dtypes)
# Out:
# ============================================================
# REPORTE COMPARATIVO - ANTES vs DESPUÉS DE LIMPIEZA
# ============================================================
#
# 📊 Análisis de Nulos por Columna:
# ------------------------------------------------------------
# Columna              Antes           Después         Mejora
# ------------------------------------------------------------
# transaction_id       0 (0.0%) 0 (0.0%) +0
# date                 0 (0.0%) 0 (0.0%) +0
# customer_id          7 (6.7%) 0 (0.0%) +7
# amount               7 (6.7%) 7 (6.7%) +0
# status               25 (23.8%) 0 (0.0%) +25
# store                19 (18.1%) 0 (0.0%) +19
#
# ✓ Estadísticas del dataset limpio:
#   - Registros totales: 105
#   - Registros sin nulos en ninguna columna: 98
#   - Registros con al menos un nulo: 7
#
# Tipos de datos después de limpieza:
# transaction_id     object
# date               object
# customer_id        object
# amount            float64
# status             object
# store              object
# dtype: object

# %% [markdown]
# ## 5. Guardar archivos de salida

# %%
print("\n" + "="*60)
print("GUARDANDO ARCHIVOS")
print("="*60)

# Guardar dataset limpio
clean_csv_path = output_dir / "transacciones_clean.csv"
df_clean.to_csv(clean_csv_path, index=False)
print(f"\n✓ Dataset limpio guardado en: {clean_csv_path}")

# Guardar reporte de limpieza
reporte_path = output_dir / "reporte_limpieza.json"
with open(reporte_path, 'w', encoding='utf-8') as f:
    json.dump(reporte, f, ensure_ascii=False, indent=2)
print(f"✓ Reporte guardado en: {reporte_path}")

# Listar archivos creados
print("\n📁 Archivos generados:")
print("-" * 60)
for archivo in output_dir.glob("*"):
    if archivo.is_file():
        tamaño = archivo.stat().st_size
        print(f"  - {archivo.name} ({tamaño:,} bytes)")
# Out:
# ============================================================
# GUARDANDO ARCHIVOS
# ============================================================
#
# ✓ Dataset limpio guardado en: /home/jovyan/work/homeworks/output/transacciones_clean.csv
# ✓ Reporte guardado en: /home/jovyan/work/homeworks/output/reporte_limpieza.json
#
# 📁 Archivos generados:
# ------------------------------------------------------------
#   - reporte_limpieza.json (1,109 bytes)
#   - transacciones_clean.csv (6,264 bytes)

# %% [markdown]
# ## 6. Resumen de la Tarea 2

# %%
print("\n" + "🎉 " * 15)
print("\n✅ TAREA 2 COMPLETADA EXITOSAMENTE")
print("\n" + "🎉 " * 15)

print("\n📋 ENTREGABLES COMPLETADOS:")
print("-" * 60)
print("✓ Función limpiar_montos() - Implementada")
print("✓ Función estandarizar_fechas() - Implementada")
print("✓ Función corregir_estados() - Implementada")
print("✓ Función corregir_tiendas() - Implementada")
print("✓ Función corregir_clientes() - Implementada")
print("✓ Aplicación de todas las funciones - Realizada")
print(f"✓ Archivo transacciones_clean.csv - Guardado")
print(f"✓ Reporte de limpieza (JSON) - Guardado")

print("\n📊 ESTADÍSTICAS FINALES:")
print("-" * 60)
print(f"Total de registros procesados: {len(df_clean)}")
print(f"Registros completamente limpios (sin nulos): {df_clean.dropna().shape[0]}")
print(f"Mejora general en calidad de datos: Completada")
# Out:
# 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉
#
# ✅ TAREA 2 COMPLETADA EXITOSAMENTE
#
# 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉 🎉
#
# 📋 ENTREGABLES COMPLETADOS:
# ------------------------------------------------------------
# ✓ Función limpiar_montos() - Implementada
# ✓ Función estandarizar_fechas() - Implementada
# ✓ Función corregir_estados() - Implementada
# ✓ Función corregir_tiendas() - Implementada
# ✓ Función corregir_clientes() - Implementada
# ✓ Aplicación de todas las funciones - Realizada
# ✓ Archivo transacciones_clean.csv - Guardado
# ✓ Reporte de limpieza (JSON) - Guardado
#
# 📊 ESTADÍSTICAS FINALES:
# ------------------------------------------------------------
# Total de registros procesados: 20000
# Registros completamente limpios (sin nulos): 10908
# Mejora general en calidad de datos: Completada
